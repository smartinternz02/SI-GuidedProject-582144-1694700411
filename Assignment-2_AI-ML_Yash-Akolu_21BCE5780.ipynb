# %% [markdown]
# #***((TASK-1))***  **Downloading the Dataset from the given Link**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %% [markdown]
# #***((TASK-2))*** **Loading the Dataset**

# %%
ds = pd.read_csv('/content/House Price India.csv')
ds
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
ds.head(344)
# Out:
#              id   Date  number of bedrooms  number of bathrooms  living area  \
# 0    6762810145  42491                   5                 2.50         3650
# 1    6762810635  42491                   4                 2.50         2920
# 2    6762810998  42491                   5                 2.75         2910
# 3    6762812605  42491                   4                 2.50         3310
# 4    6762812919  42491                   3                 2.00         2710
# ..          ...    ...                 ...                  ...          ...
# 339  6762810889  42497                   4                 3.25         3820
# 340  6762811336  42497                   4                 3.00         2920
# 341  6762811390  42497                   4                 1.00         3410
# 342  6762811575  42497                   3                 2.75         2015
# 343  6762811596  42497                   5                 2.50         3160
#
# ...

# %% [markdown]
# #***((TASK-3))***  **Performing the visualizations**

# %% [markdown]
# **(1) Univariate Analysis**

# %%
sns.distplot(ds.Lattitude)
# Out:
# <ipython-input-5-35ed4984a6fa>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds.Lattitude)
# <Axes: xlabel='Lattitude', ylabel='Density'>

# %%
sns.distplot(ds.Longitude)
# Out:
# <ipython-input-6-e3f51d54682f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds.Longitude)
# <Axes: xlabel='Longitude', ylabel='Density'>

# %%
sns.distplot(ds['number of bathrooms'])
# Out:
# <ipython-input-8-0b3a818e0ccf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ds['number of bathrooms'])
# <Axes: xlabel='number of bathrooms', ylabel='Density'>

# %%
plt.pie(ds['number of bedrooms'].value_counts(),autopct ='%1.1f%%',shadow = True,colors = ['yellow','green'],)
plt.title('Bedrooms')
plt.show()

# %% [markdown]
# **(2) Bivariate Analyis**

# %%
sns.jointplot(x='Built Year' , y='living_area_renov' , data=ds.head(344))

# %%
sns.boxplot(ds['Lattitude'])
# Out:
# <Axes: >

# %%
sns.scatterplot(ds['number of floors'])
# Out:
# <Axes: ylabel='number of floors'>

# %%
sns.lineplot(x = ds['number of bedrooms'] , y = ds['condition of the house'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='condition of the house'>

# %% [markdown]
# **(3) Multivariate Analysis**

# %%
sns.heatmap(ds.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(ds.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(ds.head(10))

# %% [markdown]
# #***((TASK-4))*** **Descriptive Statistics**

# %%
ds.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
ds.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
ds.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
ds.shape
# Out:
# (14620, 23)

# %%
ds['Date']
# Out:
# 0        42491
# 1        42491
# 2        42491
# 3        42491
# 4        42491
#          ...
# 14615    42734
# 14616    42734
# 14617    42734
# 14618    42734
# 14619    42734
# Name: Date, Length: 14620, dtype: int64

# %% [markdown]
# #***((TASK-5)***) **Handle the missing values**

# %%
missing_values = ds.isna()

# %%
ds_filled = ds.fillna(ds.mean())

# %%
missing_values_after_fill = ds_filled.isnull()

# %%
ds.isna()
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0      False  False               False                False        False
# 1      False  False               False                False        False
# 2      False  False               False                False        False
# 3      False  False               False                False        False
# 4      False  False               False                False        False
# ...      ...    ...                 ...                  ...          ...
# 14615  False  False               False                False        False
# 14616  False  False               False                False        False
# 14617  False  False               False                False        False
# 14618  False  False               False                False        False
# 14619  False  False               False                False        False
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
ds
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...
