# %% [markdown]
# #***((TASK-1))*** Downloading the Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #***((TASK-2))*** Loading the Dataset

# %%
df = pd.read_csv('/content/penguins_size.csv')

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# #***((TASK-3))*** Performing the Visualisations
# ***--------- (1) Univariate Analysis ---------***

# %%
sns.distplot(df['culmen_length_mm'])
# Out:
# <ipython-input-4-87f900721a46>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['culmen_length_mm'])
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.lineplot(df['flipper_length_mm'])
# Out:
# <Axes: ylabel='flipper_length_mm'>

# %%
sns.distplot(df['culmen_depth_mm'])
plt.grid()
# Out:
# <ipython-input-6-2695ec979d21>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['culmen_depth_mm'])

# %%
word_to_count = 'Gentoo'

count = df['species'].str.count(word_to_count).sum()

print(f'The word {word_to_count} appears {count} times.')
# Out:
# The word Gentoo appears 124 times.

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
plt.pie(df.species.value_counts(),[0.1,0.1,0.1], shadow=True, colors=['green','red','blue'], autopct='%1.1f%%', labels=['Adelie', 'Gentoo', 'Chinstrap'])
plt.title("PENGUINS")
# Out:
# Text(0.5, 1.0, 'PENGUINS')

# %%
df.species.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df.sex.unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %% [markdown]
# ***--------- (2) Bivariate Analysis ---------***

# %%
sns.lineplot(x=df['culmen_length_mm'], y=df['flipper_length_mm'])
plt.grid()

# %%
sns.lineplot(x=df['body_mass_g'], y=df['culmen_depth_mm'])
plt.grid()

# %%
sns.jointplot(x=df.species, y=df['culmen_length_mm'])

# %% [markdown]
# ***--------- (3) Multivariate Analysis ---------***

# %%
sns.pairplot(df)

# %% [markdown]
# #***((TASK-4))*** Descriptive Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.shape
# Out:
# (344, 7)

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# #***((TASK-5))*** Missing Values

# %%
df.isnull()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      False   False             False            False              False
# 1      False   False             False            False              False
# 2      False   False             False            False              False
# 3      False   False              True             True               True
# 4      False   False             False            False              False
# ..       ...     ...               ...              ...                ...
# 339    False   False              True             True               True
# 340    False   False             False            False              False
# 341    False   False             False            False              False
# 342    False   False             False            False              False
# 343    False   False             False            False              False
#
#      body_mass_g    sex
# 0          False  False
# ...

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %% [markdown]
# #------------------------------------------------------------------------
# #***((TASK-6))*** Outlier Detection and Replacing
# #------------------------------------------------------------------------

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
sns.boxplot(df['body_mass_g'])
# Out:
# <Axes: >

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
sns.boxplot(df['culmen_length_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['flipper_length_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['culmen_depth_mm'])
# Out:
# <Axes: >

# %% [markdown]
# # ---------------------- As we can see, there are no outliers. ----------------------

# %% [markdown]
# #---------------------------------------------------------------------------------------------------------
# #***((TASK-7))*** Checking the correlation of independent variables
# #---------------------------------------------------------------------------------------------------------

# %%
df.corr()
# Out:
# <ipython-input-64-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235053           0.656181
# culmen_depth_mm           -0.235053         1.000000          -0.583851
# flipper_length_mm          0.656181        -0.583851           1.000000
# body_mass_g                0.595110        -0.471916           0.871202
#
#                    body_mass_g
# culmen_length_mm      0.595110
# culmen_depth_mm      -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# Out:
# <ipython-input-65-038fc9e360ab>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
# <Axes: >

# %% [markdown]
# #***((TASK-8))*** Check for Categorical columns and perform encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.sex = le.fit_transform(df.sex)
df.island = le.fit_transform(df.island)
df.species = le.fit_transform(df.species)

# %%
df.sex
# Out:
# 0      2
# 1      1
# 2      1
# 3      3
# 4      1
#       ..
# 339    3
# 340    1
# 341    2
# 342    1
# 343    2
# Name: sex, Length: 344, dtype: int64

# %%
df.island
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 339    0
# 340    0
# 341    0
# 342    0
# 343    0
# Name: island, Length: 344, dtype: int64

# %%
df.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2              39.1             18.7              181.0
# 1        0       2              39.5             17.4              186.0
# 2        0       2              40.3             18.0              195.0
# 3        0       2               NaN              NaN                NaN
# 4        0       2              36.7             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    2
# 1       3800.0    1
# 2       3250.0    1
# 3          NaN    3
# 4       3450.0    1

# %% [markdown]
# #***((TASK-9))*** Split the data into dependent and independent variables.

# %%
df_main = pd.get_dummies(df,columns =['species'])
df_main.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2              39.1             18.7              181.0       3750.0
# 1       2              39.5             17.4              186.0       3800.0
# 2       2              40.3             18.0              195.0       3250.0
# 3       2               NaN              NaN                NaN          NaN
# 4       2              36.7             19.3              193.0       3450.0
#
#    sex  species_0  species_1  species_2
# 0    2          1          0          0
# 1    1          1          0          0
# 2    1          1          0          0
# 3    3          1          0          0
# 4    1          1          0          0

# %%
df_main.corr()
# Out:
#                      island  culmen_length_mm  culmen_depth_mm  \
# island             1.000000         -0.353647         0.571035
# culmen_length_mm  -0.353647          1.000000        -0.235053
# culmen_depth_mm    0.571035         -0.235053         1.000000
# flipper_length_mm -0.565825          0.656181        -0.583851
# body_mass_g       -0.561515          0.595110        -0.471916
# sex                0.043476          0.269434         0.322860
# species_0          0.478341         -0.836780         0.538917
# species_1          0.230823          0.448853         0.320700
# species_2         -0.686207          0.492547        -0.824357
#
#                    flipper_length_mm  body_mass_g       sex  species_0  \
# island                     -0.565825    -0.561515  0.043476   0.478341
# culmen_length_mm            0.656181     0.595110  0.269434  -0.836780
# culmen_depth_mm            -0.583851    -0.471916  0.322860   0.538917
# ...

# %%
sns.heatmap(df_main.corr(),annot =True)
# Out:
# <Axes: >

# %%
df_main.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2              39.1             18.7              181.0       3750.0
# 1       2              39.5             17.4              186.0       3800.0
# 2       2              40.3             18.0              195.0       3250.0
# 3       2               NaN              NaN                NaN          NaN
# 4       2              36.7             19.3              193.0       3450.0
#
#    sex  species_0  species_1  species_2
# 0    2          1          0          0
# 1    1          1          0          0
# 2    1          1          0          0
# 3    3          1          0          0
# 4    1          1          0          0

# %%
y = df['sex']
y
# Out:
# 0      2
# 1      1
# 2      1
# 3      3
# 4      1
#       ..
# 339    3
# 340    1
# 341    2
# 342    1
# 343    2
# Name: sex, Length: 344, dtype: int64

# %%
X = df.drop(columns =['sex'],axis =1)
X.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0        0       2              39.1             18.7              181.0
# 1        0       2              39.5             17.4              186.0
# 2        0       2              40.3             18.0              195.0
# 3        0       2               NaN              NaN                NaN
# 4        0       2              36.7             19.3              193.0
#
#    body_mass_g
# 0       3750.0
# 1       3800.0
# 2       3250.0
# 3          NaN
# 4       3450.0

# %% [markdown]
# #***((TASK-10))*** Scaling on data

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler()

# %%
X_scaled = pd.DataFrame(scale.fit_transform(X), columns=X.columns)
X_scaled.head()
# Out:
#    species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0      0.0     1.0          0.254545         0.666667           0.152542
# 1      0.0     1.0          0.269091         0.511905           0.237288
# 2      0.0     1.0          0.298182         0.583333           0.389831
# 3      0.0     1.0               NaN              NaN                NaN
# 4      0.0     1.0          0.167273         0.738095           0.355932
#
#    body_mass_g
# 0     0.291667
# 1     0.305556
# 2     0.152778
# 3          NaN
# 4     0.208333

# %% [markdown]
# #***((TASK-11 & 12))*** Training , Testing , Check_Shape

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=10)

# %%
X_train.head()
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 258      1.0     0.0          0.432727         0.059524           0.610169
# 332      1.0     0.0          0.414545         0.250000           0.694915
# 121      0.0     1.0          0.203636         0.797619           0.440678
# 61       0.0     0.0          0.334545         0.952381           0.389831
# 70       0.0     1.0          0.050909         0.702381           0.305085
#
#      body_mass_g
# 258     0.458333
# 332     0.541667
# 121     0.222222
# 61      0.472222
# 70      0.250000

# %%
X_train.shape
# Out:
# (240, 6)

# %%
X_test.shape
# Out:
# (104, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
y_test.shape
# Out:
# (104,)

# %% [markdown]
# # ***-------------------------- THE END ---------------------------***
#
# # - Yash Akolu
